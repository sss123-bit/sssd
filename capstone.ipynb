# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
col_name=['age','workclass','fnlwgt','education',
          'education-num','marital-status','occupation',
          'relationship','race','sex','capital-gain',
          'capital-loss','hours-per-week','native-country','salary']
df=pd.read_csv('adult.csv',names=col_name)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
df.replace(to_replace=' ?',value=np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# salary               0
# dtype: int64

# %%
df['native-country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
# ...

# %%
df['native-country'].mode()
# Out:
# 0     United-States
# dtype: object

# %%
df['native-country'].fillna(df['native-country'].mode().values[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
df['workclass'].fillna(df['workclass'].mode().values[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
df.groupby(['education']).agg({'occupation' : lambda x:x.mode()}).reset_index()
# Out:
#         education       occupation
# 0            10th    Other-service
# 1            11th    Other-service
# 2            12th    Other-service
# 3         1st-4th    Other-service
# 4         5th-6th    Other-service
# 5         7th-8th     Craft-repair
# 6             9th    Other-service
# 7      Assoc-acdm     Adm-clerical
# 8       Assoc-voc     Craft-repair
# 9       Bachelors   Prof-specialty
# 10      Doctorate   Prof-specialty
# 11        HS-grad     Craft-repair
# 12        Masters   Prof-specialty
# 13      Preschool    Other-service
# 14    Prof-school   Prof-specialty
# 15   Some-college     Adm-clerical

# %%
df.tail(20)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 32541   41            Private  202822        HS-grad              9
# 32542   72            Private  129912        HS-grad              9
# 32543   45          Local-gov  119199     Assoc-acdm             12
# 32544   31            Private  199655        Masters             14
# 32545   39          Local-gov  111499     Assoc-acdm             12
# 32546   37            Private  198216     Assoc-acdm             12
# 32547   43            Private  260761        HS-grad              9
# 32548   65   Self-emp-not-inc   99359    Prof-school             15
# 32549   43          State-gov  255835   Some-college             10
# 32550   43   Self-emp-not-inc   27242   Some-college             10
# 32551   32            Private   34066           10th              6
# 32552   43            Private   84661      Assoc-voc             11
# 32553   32            Private  116138        Masters             14
# ...

# %%
df.loc[(df['education'] == 'HS-grad') & (df['occupation'].isnull()),'occupation']='Craft-repair'
df.tail(20)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 32541   41            Private  202822        HS-grad              9
# 32542   72            Private  129912        HS-grad              9
# 32543   45          Local-gov  119199     Assoc-acdm             12
# 32544   31            Private  199655        Masters             14
# 32545   39          Local-gov  111499     Assoc-acdm             12
# 32546   37            Private  198216     Assoc-acdm             12
# 32547   43            Private  260761        HS-grad              9
# 32548   65   Self-emp-not-inc   99359    Prof-school             15
# 32549   43          State-gov  255835   Some-college             10
# 32550   43   Self-emp-not-inc   27242   Some-college             10
# 32551   32            Private   34066           10th              6
# 32552   43            Private   84661      Assoc-voc             11
# 32553   32            Private  116138        Masters             14
# ...

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
df.fillna(value=df['occupation'].mode().values[0],inplace=True)
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
df['age'].plot(kind='box')

# %%
df.describe().transpose()
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education-num   32561.0      10.080679       2.572720      1.0       9.0
# capital-gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital-loss    32561.0      87.303830     402.960219      0.0       0.0
# hours-per-week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education-num       10.0      12.0       16.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %%
q1=df['age'].quantile(0.25)
q3=df['age'].quantile(0.75)
iqr=q3-q1

# %%
low_value=q1-(1.5*iqr)
high_value=q3+(1.5*iqr)
low_value
# Out:
# -2.0

# %%
df=df.loc[(df['age']>low_value) & (df['age']<high_value)]
df['fnlwgt'].plot(kind='box')

# %%
q1_fnlwgt=df['fnlwgt'].quantile(0.25)
q3_fnlwgt=df['fnlwgt'].quantile(0.75)
iqr_fnlwgt=q3_fnlwgt-q1_fnlwgt
low_value_fnlwgt=q1_fnlwgt-(1.5*iqr_fnlwgt)
high_value_fnlwgt=q3_fnlwgt+(1.5*iqr_fnlwgt)

# %%
df=df.loc[(df['fnlwgt']>low_value_fnlwgt) & (df['fnlwgt']<high_value_fnlwgt)]
df['fnlwgt'].plot(kind='box')

# %%
indexNames = df[df['capital-gain']>1].index
df.drop(indexNames,inplace=True)
df['capital-gain'].plot(kind='box')

# %%
df
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# 13      32            Private  205019     Assoc-acdm             12
# 14      40            Private  121772      Assoc-voc             11
# 15      34            Private  245487        7th-8th              4
# ...

# %%
plt.scatter(x=df['hours-per-week'],y=df['salary'])

# %%
sns.catplot('salary','hours-per-week',data=df)

# %%
plt.plot(x=df['hours-per-week'],y=df['salary'])
# Out:
# []

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 5   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 1             0             0              13   United-States   <=50K
# ...

# %%
df['native-country'] = df['native-country'].astype('category').cat.codes
df['salary'] = df['salary'].astype('category').cat.codes
df['occupation'] = df['occupation'].astype('category').cat.codes
df['education'] = df['education'].astype('category').cat.codes
df['workclass'] = df['workclass'].astype('category').cat.codes
df['relationship'] = df['relationship'].astype('category').cat.codes
df['marital-status'] = df['marital-status'].astype('category').cat.codes
df[df.iloc[:,13]==39]
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 2259    38          1  123983          9             13               4
# 2653    19          3  115248         15             10               4
# 3708    36          3  160120         11              9               2
# 3832    24          3  123983          1              7               2
# 3879    43          3  128212          4              3               2
# 4168    23          3  125491         15             10               4
# 4262    20          3  133352         15             10               4
# 4826    20          3  147171         15             10               4
# 4919    23          3  244408         15             10               4
# 5395    22          3  304710          9             13               4
# 5415    23          3   73514         11              9               4
# 6175    30          3  268575         11              9               4
# ...

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 1   50          5   83311          9             13               2
# 2   38          3  215646         11              9               0
# 3   53          3  234721          1              7               2
# 4   28          3  338409          9             13               2
# 5   37          3  284582         12             14               2
#
#    occupation  relationship    race      sex  capital-gain  capital-loss  \
# 1           3             0   White     Male             0             0
# 2           5             1   White     Male             0             0
# 3           5             0   Black     Male             0             0
# 4           9             5   Black   Female             0             0
# 5           3             5   White   Female             0             0
#
#    hours-per-week  native-country  salary
# 1              13              38       0
# ...

# %%
df.corr()
# Out:
#                      age  workclass    fnlwgt  education  education-num  \
# age             1.000000   0.037072 -0.065841  -0.011754       0.025650
# workclass       0.037072   1.000000 -0.023540   0.004424       0.001612
# fnlwgt         -0.065841  -0.023540  1.000000  -0.023013      -0.035752
# education      -0.011754   0.004424 -0.023013   1.000000       0.362874
# education-num   0.025650   0.001612 -0.035752   0.362874       1.000000
# marital-status -0.288294  -0.019441  0.031141  -0.034016      -0.060298
# occupation     -0.001731   0.004464 -0.003356  -0.045935       0.063789
# relationship   -0.267805  -0.059291  0.005880  -0.011331      -0.088657
# capital-gain         NaN        NaN       NaN        NaN            NaN
# capital-loss    0.066941   0.004611 -0.002112   0.018246       0.093427
# hours-per-week  0.093068   0.040546 -0.018306   0.053814       0.137043
# native-country -0.005153  -0.000713 -0.063742   0.076746       0.083889
# ...

# %%
df.plot(x='salary',y='occupation',kind='line')

# %% [markdown]
# ## outlier detection using percentile

# %%
def outlier_detector(datacolumn,percentile):
    sorted(datacolumn)
    Q1,Q3=np.perecentile(datacolumn,[100-percentile,percentile])
    IQR=Q3-Q1
    lower_range=Q1-(1.5*IQR)
    upper_range=Q3-(1.5*IQR)
    return lower_range,upper_range
