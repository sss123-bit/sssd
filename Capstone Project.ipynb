# %%
import pandas as pd  
import matplotlib.pyplot as plt
import numpy as np

# %%
an=pd.read_table("adult.names",sep='|')

# %%
ad=pd.read_csv("adultdata.csv",sep=',',names=["Age","workclass","flnwgt","edu-status","education-num","marital-status","m-c-s","relationship","race","Gender","Capital-gain","capital-loss","hrs-per-week","native-country","salary"])
ad
# Out:
#        Age          workclass  flnwgt     edu-status  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# ...

# %%
ad=ad.replace({' ?':np.nan})

# %%
ad
# Out:
#        Age          workclass  flnwgt     edu-status  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# ...

# %%
ad['flnwgt'].plot(kind="box",figsize = (10,7))

# %%
ad['education-num'].plot(kind="box",figsize = (10,7))

# %%
ad['Capital-gain'].plot(kind="box",figsize = (10,7))

# %%
ad['hrs-per-week'].plot(kind="box",figsize = (10,7))

# %%
from scipy import stats

# %%
q1=stats.zscore(ad['education-num'])

# %%
q1
# Out:
# array([ 1.13473876,  1.13473876, -0.42005962, ..., -0.42005962,
#        -0.42005962, -0.42005962])

# %%
q1=np.abs(q1)

# %%
q1
# Out:
# array([1.13473876, 1.13473876, 0.42005962, ..., 0.42005962, 0.42005962,
#        0.42005962])

# %%
fe=(q1<1).all(axis=0)
ss=fe

# %%
ss
# Out:
# False

# %%
ad.describe()
# Out:
#                 Age        flnwgt  education-num  Capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hrs-per-week
# count  32561.000000
# mean      40.437456
# std       12.347429
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
q1=ad['education-num'].quantile(0.25)
q3=ad['education-num'].quantile(0.75) 
iqr=q3-q1
od=q1-1.5*iqr
ou=q3+1.5*iqr
nad=ad.loc[(ad['education-num']>od) & (ad['education-num']<ou)]
nad
# Out:
#        Age          workclass  flnwgt     edu-status  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# ...

# %%
nad['education-num'].plot(kind="box",figsize = (10,7))

# %%
q1=ad['hrs-per-week'].quantile(0.25)
q3=ad['hrs-per-week'].quantile(0.75) 
iqr=q3-q1
od=q1-1.5*iqr
ou=q3+1.5*iqr
nad=ad.loc[(ad['hrs-per-week']>od) & (ad['hrs-per-week']<ou)]
nad
# Out:
#        Age          workclass  flnwgt     edu-status  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 11      30          State-gov  141297      Bachelors             13
# 13      32            Private  205019     Assoc-acdm             12
# 14      40            Private  121772      Assoc-voc             11
# 15      34            Private  245487        7th-8th              4
# 16      25   Self-emp-not-inc  176756        HS-grad              9
# ...

# %%
nad['hrs-per-week'].plot(kind="box",figsize = (10,7))

# %%
q1=ad['flnwgt'].quantile(0.25)
q3=ad['flnwgt'].quantile(0.75) 
iqr=q3-q1
od=q1-1.5*iqr
ou=q3+1.5*iqr
nad=ad.loc[(ad['flnwgt']>15000) & (ad['flnwgt']<39000)]
nad
# Out:
#        Age          workclass  flnwgt     edu-status  education-num  \
# 18      38            Private   28887           11th              7
# 50      25            Private   32275   Some-college             10
# 76      40            Private   32214     Assoc-acdm             12
# 138     20            Private   34310   Some-college             10
# 160     68                NaN   38317        1st-4th              2
# 168     18            Private   25828           11th              7
# 179     33            Private   37274      Bachelors             13
# 184     37        Federal-gov   29054   Some-college             10
# 199     24   Self-emp-not-inc   32921        HS-grad              9
# 207     35            Private   36270        HS-grad              9
# 226     60                NaN   24215           10th              6
# 253     19          Local-gov   27382   Some-college             10
# 267     64            Private   21174        HS-grad              9
# ...

# %%
nad['flnwgt'].plot(kind="box",figsize = (10,7))

# %% [markdown]
# ad.describe()

# %%
ad.isnull().sum()
# Out:
# Age                  0
# workclass         1836
# flnwgt               0
# edu-status           0
# education-num        0
# marital-status       0
# m-c-s             1843
# relationship         0
# race                 0
# Gender               0
# Capital-gain         0
# capital-loss         0
# hrs-per-week         0
# native-country     583
# salary               0
# dtype: int64

# %%
nad
# Out:
#        Age          workclass  flnwgt     edu-status  education-num  \
# 18      38            Private   28887           11th              7
# 50      25            Private   32275   Some-college             10
# 76      40            Private   32214     Assoc-acdm             12
# 138     20            Private   34310   Some-college             10
# 160     68                NaN   38317        1st-4th              2
# 168     18            Private   25828           11th              7
# 179     33            Private   37274      Bachelors             13
# 184     37        Federal-gov   29054   Some-college             10
# 199     24   Self-emp-not-inc   32921        HS-grad              9
# 207     35            Private   36270        HS-grad              9
# 226     60                NaN   24215           10th              6
# 253     19          Local-gov   27382   Some-college             10
# 267     64            Private   21174        HS-grad              9
# ...

# %%
ad=ad.replace({' >50K':1})

# %%
ad=ad.replace({' <=50K':0})

# %%
ad=ad.replace({' >=50K':1})

# %%
ad=ad.replace({' <50K':0})

# %%
ad.describe()
# Out:
#                 Age        flnwgt  education-num  Capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hrs-per-week        salary
# count  32561.000000  32561.000000
# mean      40.437456      0.240810
# std       12.347429      0.427581
# min        1.000000      0.000000
# 25%       40.000000      0.000000
# 50%       40.000000      0.000000
# ...

# %%
ad=ad['Age'].replace({np.nan:int(x)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-d1443fc8381b> in <module>
# ----> 1 ad=ad['Age'].replace({np.nan:int(x)})
#
# NameError: name 'x' is not defined

# %%
ad.isna().sum()

# %%
ss=ad.groupby(by=['workclass']).size()

# %%
ss

# %%
ad['workclass'].replace()
