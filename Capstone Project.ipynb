# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
cp=pd.read_table('C:/Users/siddharth21.TRN/Downloads/AdultDataset/adult.data',sep=',')
cp
# Out:
#        39          State-gov   77516      Bachelors   13  \
# 0      50   Self-emp-not-inc   83311      Bachelors   13
# 1      38            Private  215646        HS-grad    9
# 2      53            Private  234721           11th    7
# 3      28            Private  338409      Bachelors   13
# 4      37            Private  284582        Masters   14
# 5      49            Private  160187            9th    5
# 6      52   Self-emp-not-inc  209642        HS-grad    9
# 7      31            Private   45781        Masters   14
# 8      42            Private  159449      Bachelors   13
# 9      37            Private  280464   Some-college   10
# 10     30          State-gov  141297      Bachelors   13
# 11     23            Private  122272      Bachelors   13
# 12     32            Private  205019     Assoc-acdm   12
# 13     40            Private  121772      Assoc-voc   11
# 14     34            Private  245487        7th-8th    4
# ...

# %%
ncp=cp.rename(columns={"39":"Age"},inplace=True)

# %%
cp.columns=["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country","salary"]

# %%
cp
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 3       28            Private  338409      Bachelors             13
# 4       37            Private  284582        Masters             14
# 5       49            Private  160187            9th              5
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 7       31            Private   45781        Masters             14
# 8       42            Private  159449      Bachelors             13
# 9       37            Private  280464   Some-college             10
# 10      30          State-gov  141297      Bachelors             13
# 11      23            Private  122272      Bachelors             13
# 12      32            Private  205019     Assoc-acdm             12
# ...

# %%
cp.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
cp['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
cp['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
cp.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
cp.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
import seaborn as sb
sb.set_style('darkgrid')

# %%
sb.countplot(x='marital-status',data=cp)

# %%
sb.countplot(x='relationship',data=cp,palette='hls')

# %%
sb.countplot(x='race',data=cp)

# %%
cp['race'].value_counts()
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %%
cp['salary'].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: salary, dtype: int64

# %%
sb.countplot(x='salary',data=cp)

# %%
cp['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
import numpy as np
cp.replace({' ?':np.nan})
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 3       28            Private  338409      Bachelors             13
# 4       37            Private  284582        Masters             14
# 5       49            Private  160187            9th              5
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 7       31            Private   45781        Masters             14
# 8       42            Private  159449      Bachelors             13
# 9       37            Private  280464   Some-college             10
# 10      30          State-gov  141297      Bachelors             13
# 11      23            Private  122272      Bachelors             13
# 12      32            Private  205019     Assoc-acdm             12
# ...

# %%
cp
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 3       28            Private  338409      Bachelors             13
# 4       37            Private  284582        Masters             14
# 5       49            Private  160187            9th              5
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 7       31            Private   45781        Masters             14
# 8       42            Private  159449      Bachelors             13
# 9       37            Private  280464   Some-college             10
# 10      30          State-gov  141297      Bachelors             13
# 11      23            Private  122272      Bachelors             13
# 12      32            Private  205019     Assoc-acdm             12
# ...

# %%
bcp=cp.dropna()

# %%
bcp
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 3       28            Private  338409      Bachelors             13
# 4       37            Private  284582        Masters             14
# 5       49            Private  160187            9th              5
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 7       31            Private   45781        Masters             14
# 8       42            Private  159449      Bachelors             13
# 9       37            Private  280464   Some-college             10
# 10      30          State-gov  141297      Bachelors             13
# 11      23            Private  122272      Bachelors             13
# 12      32            Private  205019     Assoc-acdm             12
# ...

# %%
bcp.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
bcp.plot(kind='box')

# %%
bcp['age'].plot(kind='box')

# %%
q1=bcp['age'].quantile(0.25)
q3=bcp['age'].quantile(0.75)
iqr=q3-q1
od=q1-1.5*iqr
ou=q3+1.5*iqr
bcp=bcp.loc[(bcp['age']>od) & (bcp['age']<75)]

# %%
bcp['age'].plot(kind='box')

# %%
bcp.plot(kind='box')

# %%
q1=bcp['fnlwgt'].quantile(0.25)
q3=bcp['fnlwgt'].quantile(0.75)
iqr=q3-q1
od=q1-1.5*iqr
ou=q3+1.5*iqr
bcp=bcp.loc[(bcp['fnlwgt']>18500)&(bcp['fnlwgt']<40000)]

# %%
bcp['fnlwgt'].plot(kind='box')

# %%
q1=bcp['education-num'].quantile(0.25)
q3=bcp['education-num'].quantile(0.75)
iqr=q3-q1
od=q1-1.5*iqr
ou=q3+1.5*iqr
bcp=bcp.loc[(bcp['education-num']>od)&(bcp['education-num']<ou)]

# %%
bcp['education-num'].plot(kind='box')

# %%
bcp.plot(kind='box')

# %%
bcp['capital-gain'].plot(kind='box')

# %%
bcp['capital-loss'].plot(kind='box')

# %%
bcp['hours-per-week'].plot(kind='box')

# %%
q1=bcp['hours-per-week'].quantile(0.25)
q3=bcp['hours-per-week'].quantile(0.75)
iqr=q3-q1
od=q1-1.5*iqr
ou=q3+1.5*iqr
bcp=bcp.loc[(bcp['hours-per-week']>34)&(bcp['hours-per-week']<53)]

# %%
bcp['hours-per-week'].plot(kind='box')

# %%
bcp.plot(kind='box')

# %%
sb.boxplot(x='age',y='marital-status',data=bcp)

# %%
sb.regplot(x="age",y="hours-per-week",data=bcp.head(50))
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sb.pairplot(bcp.head(50),vars=["age","hours-per-week","education-num"])

# %%
sb.pairplot(bcp.head(50),vars=["age","hours-per-week"])

# %%
model.fit(X,y)
import pandas as pd
x=[""]
y=
import sklearn
from sklearn.linear_model import Linear_Regression
from sklearn.linear_model import Logistic_Regression
from sklearn.model_selection import train_test_split
bcp.corr()
model=LinearRegression(normalize=True)
print(model.score(X,y))
x_train,x_test,y_train,y_test=train_test_split(df_x,df_y,size=0.2,random_state=4)b
# Out:
#   File "<ipython-input-28-529597149653>", line 4
#     y=
#       ^
# SyntaxError: invalid syntax

# %%
q1=cars
