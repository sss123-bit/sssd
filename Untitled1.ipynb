# %%
import pandas as pd
import numpy as np

import sklearn
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
credit=pd.read_csv('C:/Users/siddharth21.TRN/Downloads/credit_risk.csv')
credit
# Out:
#       over_draft  credit_usage                  credit_history  \
# 0             <0             6  critical/other existing credit
# 1       0<=X<200            48                   existing paid
# 2    no checking            12  critical/other existing credit
# 3             <0            42                   existing paid
# 4             <0            24              delayed previously
# 5    no checking            36                   existing paid
# 6    no checking            24                   existing paid
# 7       0<=X<200            36                   existing paid
# 8    no checking            12                   existing paid
# 9       0<=X<200            30  critical/other existing credit
# 10      0<=X<200            12                   existing paid
# 11            <0            48                   existing paid
# 12      0<=X<200            12                   existing paid
# 13            <0            24  critical/other existing credit
# ...

# %%
credit['residence_since'].value_counts()
# Out:
# 4    413
# 2    308
# 3    149
# 1    130
# Name: residence_since, dtype: int64

# %%
credit['credit_history'].value_counts()
# Out:
# existing paid                     530
# critical/other existing credit    293
# delayed previously                 88
# all paid                           49
# no credits/all paid                40
# Name: credit_history, dtype: int64

# %%
le_hist=LabelEncoder()
le_hist=le_hist.fit(credit['credit_history'])
credit['credit_history']=le_hist.transform(credit['credit_history'])

# %%
credit['purpose'].value_counts()
# Out:
# radio/tv               280
# new car                234
# furniture/equipment    181
# used car               103
# business                97
# education               50
# repairs                 22
# domestic appliance      12
# other                   12
# retraining               9
# Name: purpose, dtype: int64

# %%
le_purp=LabelEncoder()
le_purp=le_purp.fit(credit['purpose'])
credit['purpose']=le_purp.transform(credit['purpose'])

# %%
credit['Average_Credit_Balance'].value_counts()
# Out:
# <100                603
# no known savings    183
# 100<=X<500          103
# 500<=X<1000          63
# >=1000               48
# Name: Average_Credit_Balance, dtype: int64

# %%
le_avg=LabelEncoder()
le_avg=le_avg.fit(credit['Average_Credit_Balance'])
credit['Average_Credit_Balance']=le_avg.transform(credit['Average_Credit_Balance'])

# %%
credit['employment'].value_counts()
# Out:
# 1<=X<4        339
# >=7           253
# 4<=X<7        174
# <1            172
# unemployed     62
# Name: employment, dtype: int64

# %%
le_emp=LabelEncoder()
le_emp=le_emp.fit(credit['employment'])
credit['employment']=le_emp.transform(credit['employment'])

# %%
credit['personal_status'].value_counts()
# Out:
# male single           548
# female div/dep/mar    310
# male mar/wid           92
# male div/sep           50
# Name: personal_status, dtype: int64

# %%
le_pers=LabelEncoder()
le_pers=le_pers.fit(credit['personal_status'])
credit['personal_status']=le_pers.transform(credit['personal_status'])

# %%
credit['housing'].value_counts()
# Out:
# own         713
# rent        179
# for free    108
# Name: housing, dtype: int64

# %%
le_hous=LabelEncoder()
le_hous=le_hous.fit(credit['housing'])
credit['housing']=le_hous.transform(credit['housing'])

# %%
credit['other_payment_plans'].value_counts()
# Out:
# none      814
# bank      139
# stores     47
# Name: other_payment_plans, dtype: int64

# %%
le_other=LabelEncoder()
le_other=le_other.fit(credit['other_payment_plans'])
credit['other_payment_plans']=le_other.transform(credit['other_payment_plans'])

# %%
credit['own_telephone'].value_counts()
# Out:
# none    596
# yes     404
# Name: own_telephone, dtype: int64

# %%
le_own=LabelEncoder()
le_own=le_own.fit(credit['own_telephone'])
credit['own_telephone']=le_own.transform(credit['own_telephone'])

# %%
credit['foreign_worker'].value_counts()
# Out:
# yes    963
# no      37
# Name: foreign_worker, dtype: int64

# %%
le_for=LabelEncoder()
le_for=le_for.fit(credit['foreign_worker'])
credit['foreign_worker']=le_for.transform(credit['foreign_worker'])

# %%
credit['class'].value_counts()
# Out:
# good    700
# bad     300
# Name: class, dtype: int64

# %%
le_class=LabelEncoder()
le_class=le_class.fit(credit['class'])
credit['class']=le_class.transform(credit['class'])

# %%
credit.columns
# Out:
# Index(['over_draft', 'credit_usage', 'credit_history', 'purpose',
#        'current_balance', 'Average_Credit_Balance', 'employment', 'location',
#        'personal_status', 'other_parties', 'residence_since',
#        'property_magnitude', 'cc_age', 'other_payment_plans', 'housing',
#        'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
# over_draft                1000 non-null object
# credit_usage              1000 non-null int64
# credit_history            1000 non-null int32
# purpose                   1000 non-null int32
# current_balance           1000 non-null int64
# Average_Credit_Balance    1000 non-null int32
# employment                1000 non-null int32
# location                  1000 non-null int64
# personal_status           1000 non-null int32
# other_parties             1000 non-null object
# residence_since           1000 non-null int64
# property_magnitude        1000 non-null object
# cc_age                    1000 non-null int64
# other_payment_plans       1000 non-null int32
# housing                   1000 non-null int32
# existing_credits          1000 non-null int64
# job                       1000 non-null object
# num_dependents            1000 non-null int64
# ...

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
credit.plot(kind='box')

# %%
oX=credit.loc[:,['credit_usage','credit_history','purpose','current_balance','Average_Credit_Balance','employment','location','personal_status','residence_since','cc_age','other_payment_plans','housing','existing_credits','own_telephone','foreign_worker']]
y=credit.loc[:,['class']]

# %%
oX
# Out:
#      credit_usage  credit_history  purpose  current_balance  \
# 0               6               1        6             1169
# 1              48               3        6             5951
# 2              12               1        2             2096
# 3              42               3        3             7882
# 4              24               2        4             4870
# 5              36               3        2             9055
# 6              24               3        3             2835
# 7              36               3        9             6948
# 8              12               3        6             3059
# 9              30               1        4             5234
# 10             12               3        4             1295
# 11             48               3        0             4308
# 12             12               3        6             1567
# 13             24               1        4             1199
# 14             15               3        4             1403
# ...

# %%
scaler=MinMaxScaler()
X=pd.DataFrame(scaler.fit_transform(oX))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
X.columns=oX.columns

# %%
X
# Out:
#      credit_usage  credit_history   purpose  current_balance  \
# 0        0.029412            0.25  0.666667         0.050567
# 1        0.647059            0.75  0.666667         0.313690
# 2        0.117647            0.25  0.222222         0.101574
# 3        0.558824            0.75  0.333333         0.419941
# 4        0.294118            0.50  0.444444         0.254209
# 5        0.470588            0.75  0.222222         0.484483
# 6        0.294118            0.75  0.333333         0.142236
# 7        0.470588            0.75  1.000000         0.368548
# 8        0.117647            0.75  0.666667         0.154561
# 9        0.382353            0.25  0.444444         0.274238
# 10       0.117647            0.75  0.444444         0.057500
# 11       0.647059            0.75  0.000000         0.223286
# 12       0.117647            0.75  0.666667         0.072466
# 13       0.294118            0.25  0.444444         0.052217
# ...

# %%
y
# Out:
#      class
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
# 5        1
# 6        1
# 7        1
# 8        1
# 9        0
# 10       0
# 11       0
# 12       1
# 13       0
# 14       1
# 15       0
# 16       1
# 17       1
# 18       0
# 19       1
# 20       1
# 21       1
# 22       1
# 23       1
# 24       1
# 25       1
# 26       1
# 27       1
# 28       1
# 29       0
# ..     ...
# 970      1
# 971      1
# 972      0
# 973      0
# 974      1
# 975      1
# 976      1
# 977      1
# 978      0
# 979      0
# 980      0
# 981      0
# 982      1
# 983      0
# 984      1
# 985      1
# 986      1
# 987      1
# 988      1
# 989      1
# 990      1
# 991      1
# 992      1
# 993      1
# 994      1
# 995      1
# 996      1
# 997      1
# 998      0
# 999      1
#
# [1000 rows x 1 columns]

# %%
X.skew()
# Out:
# credit_usage              1.094184
# credit_history           -0.490064
# purpose                   0.040150
# current_balance           1.949628
# Average_Credit_Balance    0.062229
# employment                0.224112
# location                 -0.531348
# personal_status          -0.534159
# residence_since          -0.272570
# cc_age                    1.020739
# other_payment_plans      -0.565269
# housing                   0.070804
# existing_credits          1.272576
# own_telephone             0.391868
# foreign_worker           -4.913027
# dtype: float64

# %%
import seaborn as sns
sns.set()

# %%
X.var()
# Out:
# credit_usage              0.031448
# credit_history            0.070761
# purpose                   0.072366
# current_balance           0.024123
# Average_Credit_Balance    0.077201
# employment                0.112949
# location                  0.139058
# personal_status           0.202771
# residence_since           0.135355
# cc_age                    0.041263
# other_payment_plans       0.044428
# housing                   0.070560
# existing_credits          0.037076
# own_telephone             0.241025
# foreign_worker            0.035667
# dtype: float64

# %%
sns.distplot(X['credit_usage'])
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn.model_selection import train_test_split

# %%
trainX,testX,trainy,testy=train_test_split(X,y,test_size=0.3,random_state=4)
trainX.shape
# Out:
# (700, 15)

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# pca=PCA(n_components=3)
# trainX=pca.fit_transform(trainX)
# testX=pca.transform(testX)
# trainX.shape

# %% [markdown]
# explained_variance=pca.explained_variance_ratio_

# %% [markdown]
# print(explained_variance)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from sklearn.ensemble import AdaBoostClassifier

# %%
logreg=LogisticRegression()
model1=AdaBoostClassifier(n_estimators=10)
model1=logreg.fit(trainX,trainy)
model1.score(testX,testy)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.6966666666666667

# %%
dtree=DecisionTreeClassifier(min_samples_split=10,min_impurity_decrease=0.001)
model2=AdaBoostClassifier(n_estimators=10)
model2=dtree.fit(trainX,trainy)
model2.score(testX,testy)
# Out:
# 0.6733333333333333

# %%
knn=KNeighborsClassifier(n_neighbors=1,metric='euclidean')
model3=AdaBoostClassifier(n_estimators=10)
model3=knn.fit(trainX,trainy)
model3.score(testX,testy)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.6533333333333333

# %%
svm=SVC()

model4=svm.fit(trainX,trainy)
model4.score(trainX,trainy)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.71
