# %%
import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sb
sb.set_style('whitegrid')

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import scale
from sklearn import metrics

# %%
cars=pd.read_table('Z:/FA1/Reference_material/Cars93.csv',sep=',')
cars
# Out:
#     col.no Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 0        1        Acura        Integra    Small       12.9   15.9       18.8
# 1        2        Acura         Legend  Midsize       29.2   33.9       38.7
# 2        3         Audi             90  Compact       25.9   29.1       32.3
# 3        4         Audi            100  Midsize       30.8   37.7       44.6
# 4        5          BMW           535i  Midsize       23.7   30.0       36.2
# 5        6        Buick        Century  Midsize       14.2   15.7       17.3
# 6        7        Buick        LeSabre    Large       19.9   20.8       21.7
# 7        8        Buick     Roadmaster    Large       22.6   23.7       24.9
# 8        9        Buick        Riviera  Midsize       26.3   26.3       26.3
# 9       10     Cadillac        DeVille    Large       33.0   34.7       36.3
# 10      11     Cadillac        Seville  Midsize       37.5   40.1       42.7
# ...

# %%
cars.isnull().sum()
# Out:
# col.no                 0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags                0
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
dcars=cars.describe()
dcars
# Out:
#           col.no  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count  93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean   47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std    26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min     1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%    24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%    47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%    70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max    93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
# col.no                93 non-null int64
# Manufacturer          93 non-null object
# Model                 93 non-null object
# Type                  93 non-null object
# Min.Price             93 non-null float64
# Price                 93 non-null float64
# Max.Price             93 non-null float64
# MPG.city              93 non-null int64
# MPG.highway           93 non-null int64
# AirBags               93 non-null object
# DriveTrain            93 non-null object
# Cylinders             93 non-null object
# EngineSize            93 non-null float64
# Horsepower            93 non-null int64
# RPM                   93 non-null int64
# Rev.per.mile          93 non-null int64
# Man.trans.avail       93 non-null object
# Fuel.tank.capacity    93 non-null float64
# Passengers            93 non-null int64
# Length                93 non-null int64
# ...

# %%
cars['Manufacturer'].value_counts()
# Out:
# Chevrolet        8
# Ford             8
# Dodge            6
# Mazda            5
# Pontiac          5
# Toyota           4
# Oldsmobile       4
# Volkswagen       4
# Nissan           4
# Buick            4
# Hyundai          4
# Honda            3
# Subaru           3
# Lincoln          2
# Lexus            2
# Mitsubishi       2
# Volvo            2
# Chrysler         2
# Eagle            2
# Mercury          2
# Acura            2
# Geo              2
# Mercedes-Benz    2
# Cadillac         2
# Audi             2
# BMW              1
# Plymouth         1
# Infiniti         1
# Suzuki           1
# Saab             1
# Saturn           1
# Chrylser         1
# Name: Manufacturer, dtype: int64

# %%
cars['Type'].value_counts()
# Out:
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: Type, dtype: int64

# %%
cars['AirBags'].value_counts()
# Out:
# Driver only           43
# None                  34
# Driver & Passenger    16
# Name: AirBags, dtype: int64

# %%
cars['Passengers'].value_counts()
# Out:
# 5    41
# 4    23
# 6    18
# 7     8
# 2     2
# 8     1
# Name: Passengers, dtype: int64

# %%
cars['Origin'].value_counts()
# Out:
# USA        48
# non-USA    45
# Name: Origin, dtype: int64

# %%
sb.countplot(x='Origin',data=cars,palette='hls')

# %%
sb.countplot(x='AirBags',data=cars)

# %%
sb.regplot(x='Width',y='Length',data=cars,scatter=True)

# %%
x_cols=list(cars.columns)
x_cols
# Out:
# ['col.no',
#  'Manufacturer',
#  'Model',
#  'Type',
#  'Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Man.trans.avail',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight',
#  'Origin',
#  'Make']

# %%
sb.regplot(x='Min.Price',y='Max.Price',data=cars)

# %%
plt.figure()
cars["Price"].head(20).plot(label="Prices")
plt.xticks(rotation='vertical')
plt.legend()

# %%
plt.figure()
cars['Length'].head(10).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.legend()

# %%
plt.figure()
cars['Width'].head(10).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.legend()
